# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import style

# %%
days = [1,2,3,4,5]


sleeping = [7,8,6,11,7]
eating = [2,3,4,3,2]
working = [7,8,7,2,2]
playing = [8,5,7,8,13]

# %%
plt.plot([],[], color ='m', label = 'sleeping', linewidth =5)
plt.plot([],[], color ='c', label = 'eating', linewidth =5)
plt.plot([],[], color ='r', label = 'working', linewidth =5)
plt.plot([],[], color ='k', label = 'playing', linewidth =5)


plt.stackplot(days,sleeping,eating,working,playing, colors =['m','c','r','k'])

plt.title('stackplot for activies')
plt.ylabel('y')
plt.xlabel('x')
plt.legend()
plt.show()

# %%
plt.figure(figsize =(5,5))
slice = [7,2,2,13]
activies = ['sleeping','eating','working','playing']
cols = ['c','m','r','b']
plt.pie(slice, labels = activies , colors = cols, startangle =90, shadow = True, explode =(0,0.1,0,0),autopct = '%1.1f%%')

plt.title('PIE CHART')
# Out:
# Text(0.5, 1.0, 'PIE CHART')

# %%
import numpy as np

plt.figure(figsize =(10,10))

def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)

t1 =np.arange(0.0,5.0,.01)
t2 =np.arange(0.0,5.0,0.02)

plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2))

plt.subplot(212)
plt.plot(t2, np.cos(2* np.pi*t2))
plt.show()

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Days':[1,2,3,4], 'vistors': [200,100,230,300], 'Bounce_value': [20,45,60,10]})

# %%
df
# Out:
#    Days  vistors  Bounce_value
# 0     1      200            20
# 1     2      100            45
# 2     3      230            60
# 3     4      300            10

# %%
df.set_index('Days', inplace = True)

# %%
df
# Out:
#       vistors  Bounce_value
# Days
# 1         200            20
# 2         100            45
# 3         230            60
# 4         300            10

# %%
from matplotlib import style

# %%
style.use('fivethirtyeight')

df.plot()
plt.show()

# %%
df.rename(columns ={'vistors':'Users'})
# Out:
#       Users  Bounce_value
# Days
# 1       200            20
# 2       100            45
# 3       230            60
# 4       300            10

# %%
sd = df.reindex(columns =['200', '201'])

# %%
sd
# Out:
#       200  201
# Days
# 1     NaN  NaN
# 2     NaN  NaN
# 3     NaN  NaN
# 4     NaN  NaN

# %%
ds = pd.DataFrame({'gender' :['m','f','m','m','f'] , 'lunch': ['std','free','free','std','std'] , 
                   'math':[20,45,32,55,44] , 'reading score': [41,65,28,45,65], 'writing score':[45,85,41,96,41]  })

# %%
ds
# Out:
#   gender lunch  math  reading score  writing score
# 0      m   std    20             41             45
# 1      f  free    45             65             85
# 2      m  free    32             28             41
# 3      m   std    55             45             96
# 4      f   std    44             65             41

# %%
correction = ds.corr()
import seaborn as sns

sns.heatmap(correction, xticklabels = correction.columns, yticklabels = correction.columns, annot= True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(ds)

# %%
sns.relplot(x= 'math', y = 'reading score' , hue = 'gender', data= ds)

# %%
sns.catplot(x ='math', kind ='box', data = ds)

# %%
import numpy as np

h = [2, 1, 0]
x = [3, 4, 5]
 

y = np.convolve(x, h)
y
